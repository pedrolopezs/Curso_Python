# %% [markdown]
# # Laboratorio 5 · Importar todo con *
#
# Tema 9 · Módulos

# %% [markdown]
# Este laboratorio ejecuta `04_import_todo_no_recomendado.py`. El objetivo es ver que `from modulo import *` funciona, pero no es recomendable en código profesional.

# %%
from pathlib import Path
import os

# Localiza el directorio src tanto si el notebook se abre desde Tema09/notebooks
# como si VS Code usa otro directorio de trabajo cercano.
candidatos = [
    Path.cwd().parent / "src",
    Path.cwd() / "src",
    Path.home() / "Curso_Python" / "Tema09" / "src",
]

SRC = None
for candidato in candidatos:
    if candidato.exists() and (candidato / "validaciones.py").exists():
        SRC = candidato.resolve()
        break

if SRC is None:
    raise FileNotFoundError("No se encontró el directorio Tema09/src. Abre el notebook desde Tema09/notebooks o ajusta la ruta.")

os.environ["TEMA09_SRC"] = str(SRC)
print("Directorio src:", SRC)

# %%
def mostrar_fichero(nombre: str) -> None:
    """Muestra el contenido de un fichero del directorio src."""
    ruta = SRC / nombre
    print(f"--- {ruta.relative_to(SRC)} ---")
    print(ruta.read_text(encoding="utf-8"))

# %% [markdown]
# ## 1. Revisar el script

# %%
mostrar_fichero("04_import_todo_no_recomendado.py")

# %% [markdown]
# ## 2. Ejecutar el script

# %%
# %%bash
# cd "$TEMA09_SRC"
# python - <<'PY'
# fichero_script = "04_import_todo_no_recomendado.py"
#
# with open(fichero_script, encoding="utf-8") as fichero:
#     codigo = fichero.read()
#
# namespace = {"__name__": "__main__", "__file__": fichero_script}
# exec(compile(codigo, fichero_script, "exec"), namespace)
# PY

# %% [markdown]
# ## 3. Interpretación
#
# El script puede usar directamente `puerto_valido()`, `normalizar_servicio()` y `estado_valido()`, pero el origen de esos nombres queda menos claro.
#
# En código mantenible se recomienda preferir `import modulo` o `from modulo import recurso` de forma explícita.
