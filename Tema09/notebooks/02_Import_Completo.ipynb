# %% [markdown]
# # Laboratorio 2 · Importar un módulo completo
#
# Tema 9 · Módulos

# %% [markdown]
# Este laboratorio ejecuta `01_import_completo.py`. El script importa el módulo completo con `import validaciones` y accede a sus funciones mediante `validaciones.recurso`.

# %%
from pathlib import Path
import os

# Localiza el directorio src tanto si el notebook se abre desde Tema09/notebooks
# como si VS Code usa otro directorio de trabajo cercano.
candidatos = [
    Path.cwd().parent / "src",
    Path.cwd() / "src",
    Path.home() / "Curso_Python" / "Tema09" / "src",
]

SRC = None
for candidato in candidatos:
    if candidato.exists() and (candidato / "validaciones.py").exists():
        SRC = candidato.resolve()
        break

if SRC is None:
    raise FileNotFoundError("No se encontró el directorio Tema09/src. Abre el notebook desde Tema09/notebooks o ajusta la ruta.")

os.environ["TEMA09_SRC"] = str(SRC)
print("Directorio src:", SRC)

# %%
def mostrar_fichero(nombre: str) -> None:
    """Muestra el contenido de un fichero del directorio src."""
    ruta = SRC / nombre
    print(f"--- {ruta.relative_to(SRC)} ---")
    print(ruta.read_text(encoding="utf-8"))

# %% [markdown]
# ## 1. Revisar el script

# %%
mostrar_fichero("01_import_completo.py")

# %% [markdown]
# ## 2. Ejecutar el script desde `src`

# %%
# %%bash
# cd "$TEMA09_SRC"
# python 01_import_completo.py

# %% [markdown]
# ## 3. Interpretación
#
# Esta forma de importación es clara porque el código mantiene visible el origen de cada función: `validaciones.puerto_valido()`, `validaciones.normalizar_servicio()` y `validaciones.estado_valido()`.
